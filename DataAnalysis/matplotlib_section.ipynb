# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris_df = pd.read_csv('iris.csv')

# %%
iris_df.iloc[:, :-1].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### plt.plot(x , y , color = '', marker = '', linestyle = '')

# %%
years = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
GDP = [226.45, 266.30, 349.88, 412.34, 416.40, 486.81, 580.76, 598.87, 460.29, 432.69, 384.95, 417.98, 445.35, 446.105, 463, 410.00]

# %%
plt.figure(figsize=(3, 2))
plt.plot(years, GDP, color = 'green' , marker = 'o',linestyle = ':')
# plt.savefig('gdp_per_year.png')
plt.show()

# %%
# Reference : Data Science from Scratch Book

variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# %%
plt.figure(figsize=(6, 2))

plt.plot(xs, variance, 'g-', label='variance') # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # red dot-dashed line
plt.plot(xs, total_error, 'b:', label='total error') # blue dotted line
# Because we've assigned labels to each series,
# we can get a legend for free (loc=9 means "top center")
plt.legend(loc=0)
x_font1 = {'family':'serif','color':'blue','size':20}
plt.xlabel("model complexity", fontdict=x_font1)
plt.ylabel("val")

plt.xticks(range(0, 8, 2))
# plt.yticks(bias_squareds_squared)
plt.title("The Bias-Variance Tradeoff", loc='right')
# plt.grid()
# plt.grid(axis='x', color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
X = np.arange(0, 8, 0.01) * np.pi 
y = 10 * np.sin(X)
plt.plot(X, y)

# %% [markdown]
# ## histogram (x, bins=None, )

# %%
np.random.seed(7)
np.random.randn(10)
# Out:
# array([ 1.6905257 , -0.46593737])

# %%
rng = np.random.default_rng(42)
rng.standard_normal(10)
# Out:
# array([ 0.30471708, -1.03998411,  0.7504512 ,  0.94056472, -1.95103519,
#        -1.30217951,  0.1278404 , -0.31624259, -0.01680116, -0.85304393])

# %%
rng = np.random.default_rng(43)
rng.standard_normal(10)
# Out:
# array([ 0.24422951,  0.67817832, -0.58552938, -0.90867312, -1.99183821,
#         0.97162298,  0.0166573 ,  0.20573134, -0.78359488,  1.22649803])

# %%
N_points = 100000
n_bins = 20
# Create a random number generator with a fixed seed for reproducibility
rng = np.random.default_rng(1960000)

# Generate two normal distributions
dist1 = rng.standard_normal(N_points)
dist2 = 0.4 * rng.standard_normal(N_points) + 5

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True, figsize=(5, 2))

# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(dist1, bins=n_bins)
axs[1].hist(dist2, bins=n_bins)
# Out:
# (array([1.0000e+00, 3.0000e+00, 1.4000e+01, 7.9000e+01, 3.5100e+02,
#         1.1210e+03, 3.1760e+03, 6.9900e+03, 1.2557e+04, 1.7335e+04,
#         1.9119e+04, 1.6819e+04, 1.1747e+04, 6.5050e+03, 2.8260e+03,
#         9.8300e+02, 3.0400e+02, 6.2000e+01, 7.0000e+00, 1.0000e+00]),
#  array([2.97440064, 3.16851388, 3.36262712, 3.55674037, 3.75085361,
#         3.94496685, 4.13908009, 4.33319334, 4.52730658, 4.72141982,
#         4.91553307, 5.10964631, 5.30375955, 5.49787279, 5.69198604,
#         5.88609928, 6.08021252, 6.27432577, 6.46843901, 6.66255225,
#         6.8566655 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(4, 2))
plt.hist(iris_df['sepal_length'], bins=10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(4, 2))
plt.hist(iris_df['sepal_width'], bins=20)
# Out:
# (array([ 1.,  3.,  4.,  3.,  8., 14., 14., 10., 26., 12., 19., 12.,  6.,
#          3.,  9.,  2.,  1.,  1.,  1.,  1.]),
#  array([2.  , 2.12, 2.24, 2.36, 2.48, 2.6 , 2.72, 2.84, 2.96, 3.08, 3.2 ,
#         3.32, 3.44, 3.56, 3.68, 3.8 , 3.92, 4.04, 4.16, 4.28, 4.4 ]),
#  <BarContainer object of 20 artists>)

# %%
iris_df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# ## subplot
# Call signatures::
#
#    subplot(nrows, ncols, index, **kwargs)</br>
#    subplot(pos, **kwargs)</br>
#    subplot(**kwargs)</br>
#    subplot(ax)

# %%
iris_df.head()

# %%
plt.figure(figsize=(5, 6))

plt.subplot(221)
plt.plot(X, y + 2 * np.random.randn(y.size).reshape(y.shape), color='blue')
plt.plot(X, y, color='green')

plt.subplot(222)
plt.plot(X, y, color='blue')

plt.subplot(2, 2, 3)
plt.plot(X, y, color='red')

plt.subplot(224)
plt.plot(X, y, color='yellow')

# %%
plt.figure(figsize=(5, 6))

for elm in iris_df.columns[:-1]:
    plt.subplot(220+counter)
    plt.hist(iris_df[elm])
    plt.title(elm)

# plt.subplot(221)
# plt.hist(iris_df['petal_length'])
# plt.subplot()

# %%
new_sepal_less = iris_df[iris_df['sepal_length'] < 4.5 ]['sepal_length']
new_sepal_bet = iris_df[(4.5 <= iris_df['sepal_length']) & (iris_df['sepal_length'] < 5) ]['sepal_length']
new_sepal_mor = iris_df[iris_df['sepal_length'] >= 5 ]['sepal_length']

# %%
X = iris_df['sepal_length']
y = iris_df['sepal_width']

plt.figure(figsize=(10, 10))


plt.subplot(231)
plt.scatter(X, y)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.title('sepal l vs sepal w')




plt.subplot(232)
plt.hist(new_sepal_less, bins=50)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal less than 4.5')



plt.subplot(233)
plt.hist(new_sepal_bet, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal between 4.5 and 5')


plt.subplot(234)
plt.hist(new_sepal_mor, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal more than 5')

# %%
X = iris_df['sepal_length']
y = iris_df['sepal_width']

plt.figure(figsize=(9,40))


plt.subplot2grid((10,2),(3,1))
plt.scatter(X, y)
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')

plt.title('sepal l vs sepal w')




plt.subplot2grid((10,2),(7,1))
plt.hist(new_sepal_less, bins=50)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal less than 4.5')



plt.subplot2grid((10,2),(9,1))
plt.hist(new_sepal_bet, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal between 4.5 and 5')


plt.subplot2grid((10,2),(5,0))
plt.hist(new_sepal_mor, bins=20)
plt.xlabel('val')
plt.ylabel('count')

plt.title('sepal more than 5')

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(iris_df.iloc[:, :4])
# plt.show()
# iris_df.iloc[:, :4]
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe889973130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe889973670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe889961e50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fe889973bb0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe889973e50>,
# ...
#  'means': []}

# %%
class_ = list(set(iris_df['class']))


iris_list = []
for i in class_:
    print(i)
    iris_list.append(iris_df['petal_length'][iris_df['class']==i].tolist())
    
# [iris_df['sepal_length'][iris_df['class']==i].tolist() for i in class_]
plt.figure()
plt.boxplot(iris_list, labels=class_)
    
# plt.boxplot(y)
# Out:
# virginica
# versicolor
# setosa
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe886313160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe886313580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe886302e80>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fe886313ac0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe886313d60>,
# ...
#  'means': []}

# %%
sns.boxplot(iris_df, x='sepal_length', y='class')
# Out:
# <Axes: xlabel='sepal_length', ylabel='class'>

# %%
melted = pd.melt(iris_df, id_vars=['sepal_length'], value_vars='class')
sns.boxplot(melted, x='value', y='sepal_length')
# Out:
# <Axes: xlabel='value', ylabel='sepal_length'>

# %%
# Library Import(numpy and matplotlib)
import numpy as np 

# Making a dataset
np.random.seed(15) 
data_A = np.random.normal(90, 30, 400) 
data_B = np.random.normal(160, 50, 400) 
data_C = np.random.normal(90, 40, 400) 
data_D = np.random.normal(110, 30, 400) 
_data = [data_A, data_B, data_C, data_D] 
 
_fig = plt.figure(figsize =(11, 8)) 
_ax = _fig.add_subplot(111) 
# _fig, _ax = plt.subplots(1, 1, figsize =(11, 8))
 
# Making an axis instance
_bp = _ax.boxplot(_data, patch_artist = True, notch ='True', vert = 0) 
 
_colors = ['blue', 'pink', 'red', 'orange'] 



for patch, color in zip(_bp['boxes'], _colors): 
    patch.set_facecolor(color) 
# for indx in range(len(_bp['boxes'])): _bp['boxes'][indx].set_facecolor(_colors[indx]) 
 
# # Whisker color and line width can be changed.
for whisker in _bp['whiskers']: whisker.set(color ='#8B008B', linewidth = 1.5, linestyle =":") 
 
# # color and line width of caps can be changed
for cap in _bp['caps']: cap.set(color ='#8B008B', linewidth = 2) 
 
# # Color and linewidth of medians can be changed.
for median in _bp['medians']: median.set(color ='red', linewidth = 3) 
 
# # changing style of fliers 
for flier in _bp['fliers']: flier.set(marker ='D', color ='#e7298a', alpha = 0.5) 
 
# # Labels on the x-axis
_ax.set_yticklabels(['data_A', 'data_B', 'data_C', 'data_D']) 
 
# # Including a title 
plt.title("Customized Box Plot with Labels") 
 
# # Ticks on the top and right axes are removed.
_ax.get_xaxis().tick_bottom() 
_ax.get_yaxis().tick_left() 

plt.grid(axis='x', color = 'green', linestyle = '--', linewidth = 0.5)
# # display the plt 
# plt.show(_bp)

# %% [markdown]
# ## scatter plot (x, y, c=None, marker=None, cmap=None, )

# %%
# plt.scatter(iris_df['sepal_length'], iris_df['petal_length'], c='blue', marker="D")
# plt.scatter(iris_df['sepal_length'], iris_df['sepal_width'], c='#88c999')
colors = np.arange(len(iris_df['sepal_length']))
plt.scatter(iris_df['sepal_length'], iris_df['sepal_width'], c = colors, cmap='viridis')
plt.colorbar()

# %%
plt.figure(figsize=(6, 4))
plt.title("setal_length vs setal_width")

class_ = list(set(iris_df['class']))
color_plt = {class_[0] : 'red', class_[1] : 'green', class_[2]: 'blue'}


for val in class_:
    
    temp = iris_df[iris_df['class'] == val]
    # plt.scatter(temp['petal_length'], temp['petal_width'], c= color_plt[val] , label=val)
    plt.scatter(temp['sepal_length'], temp['petal_length'], c= color_plt[val] , label=val)

    
plt.legend()
plt.xlabel('setal_length')
plt.ylabel('setal_width')
plt.show()

# %%
# TODO dataset titanic , plot

# %% [markdown]
# ## pie chart
# Make a pie chart of array x. The fractional area of each wedge is given by x/sum(x).</br>
#
# The wedges are plotted counterclockwise, by default starting from the x-axis.

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe884bf60d0>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')])

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe884bbeca0>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')],
#  [Text(0.5346039094123416, 0.2723943098543742, '15.0%'),
#   Text(-0.18541023936624987, 0.5706338958896061, '30.0%'),
#   Text(-0.27239425980114257, -0.5346039349157352, '45.0%'),
#   Text(0.5706339175888016, -0.18541017258299716, '10.0%')])

# %%
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,
       colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe884b115e0>,
# ...
#  [Text(0.9801071672559598, 0.4993895680663527, 'Frogs'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Hogs'),
#   Text(-0.49938947630209474, -0.9801072140121813, 'Dogs'),
#   Text(1.0461621822461364, -0.3399186497354948, 'Logs')])

# %%
explode = (0, 0.1, 0, 0.2)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.show()

# %%
# TODO: debug below code (code from matplotlib doc examples!)

from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.27, .56, .17]
labels = ['Approve', 'Disapprove', 'Undecided']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.33, .54, .07, .06]
age_labels = ['Under 35', '35-49', '50-65', 'Over 65']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Age of approvers')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.show()

# %% [markdown]
# ## some examples

# %%
uniform_random = np.random.uniform(0,10,10000)

# %%
plt.hist(uniform_random, bins=10)

# %%
normal_random = 2 * np.random.randn(1000) + 5

# %%
plt.hist(normal_random, bins=50)

# %%
iris_df.head()

# %%
fig = sns.displot(uniform_random,bins=100, kde=True)
fig.set(xlabel = "uniform dist", ylabel="frequency")

# %%
sns.kdeplot(normal_random, cmap="mako")

# %%
plt.figure(figsize=(9,10))

plt.subplot(2, 2, (1, 1))
plt.hist(iris_df["sepal_length"], bins=30)
plt.xlabel("sepal_length")
plt.ylabel("frequency")


plt.subplot(222)
plt.hist(iris_df["sepal_width"], bins=30)
plt.xlabel("sepal_width")
plt.ylabel("frequency")


plt.subplot(223)
plt.hist(iris_df["petal_length"], bins=30)
plt.xlabel("petal_length")
plt.ylabel("frequency")


plt.subplot(224)
plt.hist(iris_df["petal_width"], bins=30)
plt.xlabel("petal_width")
plt.ylabel("frequency")

plt.show()

# %%
iris_df.info()

# %%
iris_df.hist()

# %%
X = np.arange(0, 8, 0.01)
y = 10 * np.sin(np.pi * X)
white_noise = np.random.randn(len(y))
plt.plot(X, y + white_noise, color="r")
plt.plot(X, y)
plt.show()
