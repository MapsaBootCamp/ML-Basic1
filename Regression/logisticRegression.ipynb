# %%
from sklearn.datasets import load_iris
iris = load_iris(as_frame=True)
list(iris)

# %%
print(iris.DESCR)

# %%
iris.target_names

# %%
y = iris.target_names[iris.target] == 'virginica'
y

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

y = iris.target_names[iris.target] == 'virginica'
f = np.vectorize(lambda x: 1 if x else 0)

sns.scatterplot(x=iris.data[["petal width (cm)"]].values.flatten(), y=iris.data[["petal length (cm)"]].values.flatten(), hue=f(y).astype("float64"))
# f(y).astype("float64")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = iris.data[["petal width (cm)"]].values
y = iris.target_names[iris.target] == 'virginica'
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_predict = log_reg.predict(X_test)
y_predict
# Out:
# array([False, False, False, False, False,  True, False, False, False,
#        False, False,  True, False, False,  True,  True, False,  True,
#        False, False, False,  True,  True, False, False, False, False,
#         True, False, False])

# %%
log_reg.predict_proba(X_test)
# Out:
# array([[0.81944166, 0.18055834],
#        [0.99747337, 0.00252663],
#        [0.99432719, 0.00567281],
#        [0.5731297 , 0.4268703 ],
#        [0.75149286, 0.24850714],
#        [0.2092777 , 0.7907223 ],
#        [0.99151053, 0.00848947],
#        [0.99747337, 0.00252663],
#        [0.5731297 , 0.4268703 ],
#        [0.99432719, 0.00567281],
#        [0.75149286, 0.24850714],
#        [0.07261332, 0.92738668],
#        [0.93880296, 0.06119704],
#        [0.93880296, 0.06119704],
#        [0.2092777 , 0.7907223 ],
#        [0.2092777 , 0.7907223 ],
#        [0.66832322, 0.33167678],
#        [0.37347761, 0.62652239],
#        [0.91088813, 0.08911187],
#        [0.99747337, 0.00252663],
#        [0.99432719, 0.00567281],
#        [0.37347761, 0.62652239],
#        [0.37347761, 0.62652239],
#        [0.99831503, 0.00168497],
#        [0.99831503, 0.00168497],
#        [0.87197648, 0.12802352],
#        [0.99432719, 0.00567281],
#        [0.04958542, 0.95041458],
#        [0.99747337, 0.00252663],
#        [0.99747337, 0.00252663]])

# %%
y_test
# Out:
# array([False, False, False, False,  True,  True, False, False, False,
#        False, False,  True, False, False,  True,  True, False,  True,
#        False, False, False,  True,  True, False, False, False, False,
#         True, False, False])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

confusion_matrix(y_test, y_predict)
# Out:
# array([[21,  0],
#        [ 1,  8]])

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.9666666666666667
